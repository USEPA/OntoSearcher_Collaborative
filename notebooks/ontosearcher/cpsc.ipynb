# %% [markdown]
# #### CPSC excelt to RDF files using OntoSearcher
# This notebook is going to be walking through how to use Onto Searcher on the CPSC Compiled Nanoproducts inventory. You can either choose to use the OntoSearcher tutorial or you can use this as a guide because I will try to include some of the things that I have learned regarding using OntoSearcher as someone who knows nothing about nanomaterials
#
# key things: your project structure should look like this
# - 1. A csv folder which will have subfolders for each csv file that we have, we will convert each csv file to RDF and then try to the merge them
# - 2. The ontosearch package which should be given to you
# - 3. A folder called owlfiles which stores the different ontologies you want to map on your data: we will be using common ones like enanomapper and npo but depending on the data you might want to select more relevant ones regarding your domain
# - 4. Your .json file that has the mapped ontologies, if not look into the onto searcher tutorial notebook but I will try to redo some of the things here as well
#
# **Regarding specific ontologies: some do not work so just try to see what ones are able to match**

# %%
import pandas as pd
# Out:
# /Users/pranavsingh/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import pandas as pd
df = pd.read_csv('./cpsc_csv/Database/Database.csv')
for col in df.columns:
    print(set(df[col]))
    print()
# Out:
# {'Home Furnishings - upholstery coatings, fabric treatments', 'Household Cleaners (including Laundry Products)', 'Pet Products', 'Electronics ', 'Coatings, Paints, and Sealants (except textile)', 'Toys / Products for Children ', 'Home furnishings- textiles, Coatings, Paints, and Sealants (except textile), Healthcare', 'Tools- Personal Care', 'Household - hardware, tools', 'Luggage/Bags/Purses', 'Automotive', 'Air Purifier /Filtration, including face masks', 'Packaging', 'Jewelry', 'Home Furnishings - textiles', 'Appliances', 'Clothing (including accessories, shoes, shoe products)', 'Tools - Personal Care ', 'Medical Equipment', 'Sports Equipment'}
#
# {'Soap', 'Wax/Polish', 'Fire retardant', 'Fertilizer', 'Hearing aid', 'Chemical', 'Quantum Dots', 'Air freshener', 'Arrows', 'Mouthguard', 'Camera lense', 'Flashlight', 'Leashes/chains', 'Electrode', 'Pacifier', 'Concrete', 'Semiconductor', 'IPOD', 'Graphics card', 'kitchenware', 'Lens case', 'Glue', 'Deodorizer', 'Cushions', 'Paper', 'wetsuit', 'Wire', 'Robot', 'Hockey equipment', 'cleaner', 'Golf shaft', 'Bicycle tyres', 'Pencils', 'Towel', 'Strings', 'Swimwear', 'shirt', 'wheel', 'Wood', 'Slicer', 'Lab Equipment', 'Eye mask', 'shorts', 'Field hockey stick.', 'Bicycle equipment', 'Brace', 'Instrument Strings', 'Steam Iron', 'Kitchenware', 'Antifreezing agent', 'Fuel additive', 'Ice axe', 'Gloves', 'Training clothes', 'LED', 'Bag/purse', 'Protective equipment', 'Water bottle', 'Luggage', 'Facial damper', 'screen protector ', 'socks', 'Plastic bottles', 'Paint', 'Food storage', 'Golf equipment', 'Bat', 'Pants', 'Filter', 'Hockey Stick', 'Solar Energy', 'Stroller', 'Surfboard', 'Fabric softener', 'Cord ', 'brushes', 'Hard drive', 'Tie', 'Mouse', 'Hat', 'Shirt', 'Shoecover', 'Laundry system', 'Mold & mildew cleaner', 'Automotive oil', 'Brushes', 'Repair product', 'glasses', 'Hook', 'Glass', 'Hair iron (any type)', 'Sealant', 'Body Lotion', 'Photonics', 'Tennis ball', 'Humidifier', 'Pump', 'Cream', 'diamond', 'Generator', 'Toy', 'tracksuit', 'Water filter', 'CD Mat', 'Golf shalft', 'Umbrella', 'All Purpose Apron', 'Coatings', 'trimmer', 'Solar Cell', 'Metal', 'Wetsuit', 'Vacuum cleaner', 'TV', 'Wax/polish', 'Face mask', 'Bathtub assist', 'Refrigerator', 'keyboard', 'Solar', 'Sleepsuit', 'supporter', 'jacket', 'Golf balls.', 'Flash memory', 'Music Equipment', 'Light', 'Slippers', 'pants', 'Travel pillows', 'Camera', 'bedding', 'Computer', 'Headphones', 'Toothbrush', 'Rubber', 'Faucet/tap', 'Jacket', 'Paint Protection', 'Pillows', 'Steam iron', 'Socks', 'Key chain', 'Pencil', 'Bottle', 'Shoe insert', 'Keyboard', 'Support', 'Cleaner', 'Water Purifier ', 'Axe', 'Dog Clothes', 'Tire', 'Body suit', 'Racquet', 'Floorball stick', 'Vaccum Cleaner', 'Mattress/Bed', 'Cement', 'Tableware', 'Speakers', 'Scarf', 'Skort', 'Cycle tyre', 'Personal hygiene/make-up tools', 'Baby bottle/cup', 'Baby carriage', 'Glass bottles', 'Ski equipment', 'Golf Club', 'Sensor', 'Baby bottle brush', 'Ipod', 'Ink', 'Fishing equipment', 'Hair removal', 'Lock', 'Baseball bat', 'Bedding', 'Bicycle tire', "Clothing, children's", 'insulation', 'Helmet', 'Bicycle', 'Coffee Maker', 'Engine oil additive', 'filter', 'Air sanitizer', 'Wireless headset', 'Dog collar', 'Washing machine', 'Sunglasses', 'Underwear', 'Climbing equipment', 'Solar Cells', 'Food container', 'Vest', 'Processor', 'Fibers and Fabrics', 'Playing consol.', 'Dryer', 'Diamond', 'Shower doors', 'Car oil', 'Watch band', 'Hair dryer', 'Cameras', 'toy', 'Car rims', 'Toilet', 'Bars', 'Glove', 'Air purifier', 'Blanket, other', 'Shaver', 'Air conditioner', 'Bike equipment', 'Shorts', 'Battery', 'Knee guard', 'Razor', 'Music equipment', 'Towels', 'Bowling equipment', 'Hair Dryer'}
#
# {'Nanoquartz', 'Carbon nanotube', 'Silver, Titanium', 'Carnauba wax', 'Titanium dioxide (2-3nm)', 'Iron', 'Silver, Titanium dioxide', 'nano-quartz particles', 'Carbon', 'TPO polypropylene-based', 'Nano Nickel', 'NanoSilver', 'black glass fibre textile', 'Tungsten Carbide, Cobalt, and Chromium', 'Nano SCS', 'Nano carnauba wax', 'ceramic-polymer-hybrid coating', 'Aluminium', 'Nanoceramics ', 'Nano 8 Technology', 'Multi crosslinking polyplexins', 'aerogel', 'Sandvik Nanoflex® ', 'Nano Silver™ ', 'NanoGUARD', 'Graphene', 'NanoWeb®', 'Carbon, Fullerenes', 'calcium hydroxide nano-particles', 'Silver and titanium nanoelements', 'metallic oxides\xa0', 'copper-indium-gallium-diselenide', 'Nanofluoride', 'fluorine polyurethane acrylic polymer', 'Carbon Nanotubes', 'fullerene-like tungsten disulfide', 'PTFE and polysilazanes', 'Tiatnium', 'nFusion Technology', 'Sub-Micronized "transparent"  Titanium Dioxide ( A few nm- 10 Microns) , Sub- Micronized Zinc Oxide (80-150nm)', 'Zinc Oxide', 'Nanofiber', 'Nano photo-copper zinc', 'Hydrophobic nano particles', 'AEROTAXY®', 'nanostructured lithium-titanate', 'Ultra-Micronized Titanium Dioxide and Zince Oxide', 'polypropylene\xa0', 'Hybtonite™ epoxy (Composite resins reinforced with carbon nanotubes)', 'Self-Assembled Monolayer of Phosphonates', 'Titanium Dioxide (2-3nm)', 'polyvinylbutyral', 'Polytetrafluoroethylene', 'Nano diamond', 'Nanogold', 'Nano titanium', 'Texcote', 'Unknown', 'Nanophosphate', 'cerium oxide', 'Silver Dioxide', 'Graphite', 'silicon', 'Copper, Zinc', 'Nano metal - unspecified', 'polybutadienes', 'Steel', 'Nano Ceramic® , nano silver, nano tourmaline', 'Cordura Brand® Ballistic Fabric', 'Polytetrafluoroethyelen', 'Nano-Care™', 'Nano crystal - unspecified', 'NanoMist', 'Alpha diamond', 'Demron™', 'Nano tourmaline', 'carbon nanotubes', 'Gold, Titanium', 'Nanoscale process', 'unknown', 'Nano ceramic, Nano touramline', 'sillcon', 'Li-ion', 'Nano Diamond', 'PTFE', 'Silicon', 'Aluminum', 'Graphite, Titanium', 'Lithium', 'spherical oxide', 'Al2O3', 'Bamboo charcoal, Gold', 'Art CoolTM', 'NanoFilm Barrier Coating ', 'cycloaliphatic amine epoxy', 'Nano silicone', 'Nano Zinco Oxide (Z-cote)', '"highly micronized" Titanium Dioxide', 'Nanosphere® ', 'Thermopox', 'Nanoceramics, Nano Kiyoseki Minerals', 'aluminum oxide', 'Polyurethane', 'Nano Kiyoseki Minerals', 'Titanium', '\xa0blend of PTFE and polysilazanes', 'nano-sized carnauba particles', 'Nanowire', 'Nano silicon oxide', 'Nano Carbon Tubes', 'Fluoropolymer', 'Pilkington Activ™ coating', 'Nano zinc', 'Silicon On Insulator (SOI)', 'Nanosilver', 'Poron®', 'Nano Silica (2nm-50nm)', 'Sanagloss™ nanotechnology', 'Hydroxyapatite', 'Calcium, Unknown', 'Unspecified nanomaterials', 'Silicon dioxide', 'Nano Aluminum', 'Nano Titanium Dioxide', 'ceramic nanopaticles', 'vinyl chloride-based', 'Nanofuse™', 'Nanocopper', 'NDMX™', 'Nansulate™ ', 'Nano-Dry®', 'Nano carbon - unspecified', 'MCS® Blocker nanotechnology', 'titan compounds', 'Thermalon™ ', 'Nanocide™', 'Nano titanium dioxide', 'MAM or SAS', 'ethylene propylene diene', 'accelerate silver ionic flux', 'Nano diamond composite', 'Nano coating', 'Nanonickle', 'Nano CFC', 'Silica', 'boron nitride coating', 'Bamboo charcoal', 'germanium-on-silicon', 'Nano Filter- Nano Confined Catalytic Oxidation', 'Fullerenes', 'Nano Carnauba (leaves of the Copernicia prunifera palm) ', 'Nano Bamboo Charcoal Fibers', 'Nano-Sphere fabric finishing', 'Carbon Nanotube Metal Matrix Composite', 'Fullerene - nano carbon', 'Nanodiamond', 'gallium arsenide nanowires', 'Carbon naotubes', 'WS2, BN, PTFE, and graphite', 'Nano Zinc Oxide (40 nm-140nm)', 'Nano Silver', 'Carbon, Titanium', 'Nano Silver - 25nm', '3-(trimethoxysilyl)propyldimethyloctadecyl ammonium chloride ', 'Z-Cote® transparent zinc oxide', 'Gold', 'Nano-Tex ( nano silver)', 'Nickle', 'Nano-Tex technology', 'Silver, Unknown', 'Copper', 'Micronized Zinc Oxide', 'copper indium', 'Nano Carbon Fiber', 'Silver', 'Nano Silver ', 'Nanoprotect® CS', 'Nanotol Seala ...
#
# {'Improved product', 'scratch resistance', 'Anti-bacteria', 'Improved Thermal Conductivity', 'PTFE-free', 'Breathable', 'kills airborne contaminants', 'keeps dry', 'anti-fogging', 'anti-allergen', 'Electro Static, Anti-Bacterial, Anti Viral,Long Lasting', 'Faster', 'Anti-biotic, anti-odor', 'Improved Buoancy', 'adds fragrence', 'lighter', 'prevents brittleness', 'Transparent', 'protects surface', 'UV Protection', 'Stronger', 'lower energy use', 'Anti-bacterial', 'non-stick', 'reduces emissions', 'UV resistant', 'Lighter', 'stronger', 'thermal regulation', 'water and oil repellent', 'Spill-Resistant, Durable', 'improved product', 'breathable', 'Resists Spills', 'Anti-baterial', 'Stiffness, Impact Resistance', 'improves blood circulation and metabolism', 'Unknown', 'self-cleaning', 'Stain repellent, Deodorizing, Antibacterial, Durable, Sensitive', 'saves fuel', 'repels dirt ', 'Increased thermal conductivity', 'water repellent', 'higher heat', 'harder', 'unknown', 'stretchy', 'Anti-viral', 'Hardening, Protective surface, fills in crevices', 'more buoyant', 'Anti-Microbial', 'lead encapsulation', 'reduced water use', 'barrier against dirt', 'antibacterial', nan, 'retains tone for longer', 'Anti-bacterial, Anti-fungal, anti-odor', 'slip resistance', 'blocks radio frequency traffic ', 'UV Protection, Anti-Microbial', 'stain resistant', 'Anti-bacterial, Anti-odor', 'cleaning', 'Anti-bacterial, Anti-fungal', 'Deodorizing & Antibacterial, "Removes allergens, viruses, bacteria and TVOCs without releasing any oxidants into the air"', 'greater storage capacity', 'antifungal', 'fill cracks and crevices', 'cleans engine', 'UV protection', 'Bulletproof', 'Bullet- Proof Strength', 'traps dirt and moisture', 'Water resistant, Non-smearing', 'insulation', 'smaller, more powerful', 'Improved Blood Circulation and Anion Production', 'protection against any radiological/nuclear emergency', 'improves sleep', 'Anti-bacterial, anti-fungal', 'faster', 'dries quickly', 'prevents static build up', 'wrinkle-resistant', 'create larger product from small original', 'oil resistant', 'deodorizing', 'Anti-Bacteria, Water Resistant'}
#
# {'Kodak', 'X-Bionic', 'Winix', 'EUROVIA', 'ACUITY BRANDS LIGHTING INC.', 'Scalpmaster-Burmax Company', 'K&W', 'EV Group ', 'Dirk Rossmann GmbH', 'AkzoNobel Deco GmbH', 'Capistrano', 'Easton Sports Inc.', 'BMGK Co., Ltd.', 'Red5', 'IBZ SALZCHEMIE GMBH', 'Solano', 'Clean-X', 'GreenPan', 'Helen of Troy ', 'Sandvik', 'Teijin', 'RX Network Company, LTD', 'Sharper Image', 'Glamoriser', 'Christian Louboutin', 'PurifiCup', 'Tracie Martyn', 'Melvo', 'Percenta AG', 'Bloom Baby', 'Greenyarn LLC.', 'Pure Plushy', 'Radiation Shield Tecnologies', 'Sophie Hulme', '3M', 'TOUCHSTONE ADVANCED COMPOSITES', 'Bench', 'WTB', 'Sandvik Materials Technology', 'ARKEMA', 'K and W Products', 'Leather Care Products', 'Nanonordisk', 'ATI Radeon™', 'EASTMAN CHEMICAL', 'Black & Decker', 'CLARIANT INTERNATIONAL\xa0', 'Nano-Film Ltd', 'Valera', 'GAMMAPIU', 'BMW', 'Casanovy', 'Amepox', 'AMD', '2XU ', 'Vivienne Westwood', 'Seal America, Inc', 'G7 Productivity Systems', 'Advanced Nano-Coatings, Inc.™', 'Dulux', 'Jack Wolfskin®', 'Dynalene', 'Atomic Snow', 'Nanoexa', 'Turboion', 'PROLIMA TECH', 'Greenyard LLC', 'Unknown', 'DSM', 'BAIKOWSKI', 'TCnano ', 'Elixir® ', 'American Bowling Service Inc. (© ABS International Corporation is the international service)', 'Green Earth Technolgies Inc', 'Prolima Tech, Powerlet', 'Solvoltaics', 'CENANO', 'LafargeHolcim', 'Mountain Buggy', 'Bielmeier', 'Glenmuir', 'Spintek', 'FHI Heat', 'NONVOLATILE ELECTRONICS\xa0', 'TEXSTARS', 'Helena Rubinstein', 'ANGSTROM ENGINEERING', 'Bestnano Handels GmbH', "O'Nano", 'VINDICOAT', 'Ecofam™', 'Denver', 'Yamaha Motor', 'Easton® Sports, Bicycle Products Group ', 'Kleentek', 'WORLÉE-CHEMIE', 'Yonex', 'AJAT', 'ALPHABET ENERGY', 'SPINTEK FILTRATION\xa0', 'Victorinox Swiss Army', 'Wolfgruben Werke', 'Nitro', 'ENERDEL', 'Sunpentown', 'Shenzhen Become', 'TEKNA PLASMA SYSTEMS\xa0', 'CMI Enterprises', 'CW-X', 'C.A.M.P.', 'Contourwear™', 'Shock Doctor, Inc.', 'ABOS Handel Beier & Shulte GbR', 'A123 Systems', 'SUNPENTOWN INTERNATIONAL INC', 'ABC NANOTECH', 'Lee Jeans', 'Grafalloy®, Inc', 'Nicky Clarke', 'Silverlit', 'Lee Strafford', 'INSULCON', 'Pro Kennex', 'Matzuo', 'VILLEROY & BOCH', 'Samsung', 'ALANOD', 'Rosacea Care', 'NEI CORP', 'Atomic Show', 'Babolat', 'NanoTrade s.r.o.', 'Lands’ End Inc.', 'TRESemme', 'ADVANCED NANO PRODUCTS\xa0', 'CALIFORNIA LITHIUM BATTERY', 'Proskins', 'ESPIN TECHNOLOGIES', 'Montreal–Tackla Hockey Company \n', 'Amendment II', 'REWITEC GmbH', 'Polti Deutschland GmbH', 'Head®/Powermetal Technologies, Inc.', 'REWITEC', 'Turtle Wax', 'TK', 'Arctic Shield', 'Adekema', 'Natural Nano Inc', 'Aeykung', 'Turtle Wax Inc.', 'Cloudveil', 'Patagonia Inc.', 'Ionic Zone', 'NANOFOCUS', 'Nigrin', 'Scio Diamond Technology Corporation\n', 'Bourque Industries', 'Vktech', 'APPLIED GRAPHENE MATERIALS', 'Wigwam', 'VA-Q-TEC', 'Holmenkol AG', 'Evonik', 'Givenchy', 'Azonano', 'Odysseus', 'SUNRAY SCIENTIFIC', 'Anfiro', 'Prolima Tech, Autobright', 'ABOS Handel Beier & Schulte GbR', 'Daewoo (UK)', 'Zone 3', 'Ufesa', 'MicroPedi', 'EV GROUP E. THALLNER', 'Bio Ionic                                                                                                                                                                                                                                                                                                                                                        ', 'LG®', 'CeNano GmbH & Co. KG', 'Nanomagic', 'Discount Cleaning Supplies', 'JVC', 'Goodfellow Cambridge', 'Bosch', 'Vital Age', 'J International CityM Korea, LTD.', 'Prolima Tech, TK', 'NXP SEMICONDUCTORS NETHERLANDS', 'Elgiganten', 'Silicone', 'Amendment II American Armor', 'AZUR SPACE SOLAR POWER\xa0', 'Smith', 'Boora', 'Conair', 'Moo Sool Sa Ind. Co.', 'Sea to Summit', 'ASPEN AEROGELS', 'Chloe', 'Viola', 'Chronic nano technology', 'GRAPHENE BATTERIES', 'Stromgren Athletics', 'Hamleys', 'SureSource LLC (Remington)', 'Muc-Off', 'BOORA', 'Polarwrap', ' PERCENTA AG', 'ADVANCED OPTICS SCHOTT\xa0', 'Cannondale' ...
#
# {'https://clicks.co.za/products/view/clicks-professionals-nano-titanium-ceramic-radial-brush-large', 'https://www.amazon.com/octagon-simulated-emerald-sterling-available/dp/b01djgs350/ref=sr_1_24?ie=utf8&qid=1488891510&sr=8-24&keywords=gem+stone+king+nano', 'http://www.thebeautylounge.co.nz/product/silver-bullet-root-volumising-crimper/?v=dd65ef9a5579', 'https://www.amazon.com/smith-optics-unisex-sequel-sports/dp/b00umbfsli/ref=sr_1_1?srs=2600791011&ie=utf8&qid=1484314605&sr=8-1&keywords=sequel', 'https://shopclash.com/collections/kara/products/shearling-nano-tie-crossbody-grey', 'Exs: http://www.daewoo-electronics.de/eu/products/living_washing_prod.asp?idprod=235; http://www.samsung.com/ph/consumer/learningresources/washingmachine/silver_nano/site.html', 'https://www.nanosilver.eu/Man-s-T-shirt-nanosilver-CLASSIC-imprinted-LOGO', 'http://www.amazon.co.uk/dewalt-dc308kl-36-volt-heavy-duty-cordless/dp/b000y8w7ky ', 'https://www.fashionphile.com/celine-drummed-calfskin-nano-luggage-dune-142834', 'https://www.novacentrix.com/products/metalon-conductive-inks', 'https://www.ulta.com/ulta/browse/productdetail.jsp?productid=xlsimpprod1080004#', 'http://www.bike-discount.de/shop/a6393/textile-proof-active-250ml.html?lg=en ', 'http://www.hopevalleysaddlery.co.uk/3758/horseware-newmarket-heritage-ladies-jacket', 'https://www.ebay.com/urw/Hot-Tools-Nanotech-3100-Nano-Ceramic-1875w-Salon-Turbo-Ionic-Hair-Dryer-HTBW05/product-reviews/691414879', 'https://clicks.co.za/tresemme_volume-ceramic-plated-tunnel-vent-brush-all-hair-lengths/p/182896', 'http://www.nanoconcept.de/anti-fog.104.0.html?&l=1 ', 'http://www.amazon.de/dewalt-dc415kl-qw-akku-winkelschleifer-36v-li-ion/dp/b0013ljtrk ', 'http://www.agactive.com/towelplain.html ', 'http://www.international.boots.com/en/glamoriser-motor-hair-wand-by-richard-ward_1523711/ ', 'https://www.amazon.com/shift-nano-mainline-goggle/dp/b00u6nykwk/ref=sr_1_sc_2?ie=utf8&qid=1487854629&sr=8-2-spell&keywords=shiftmx+nano+goggles', 'https://www.plansee.com/en/products/thin-film-material/sputtering-targets-and-arcing-cathodes/molybdenum.html', 'https://www.tennisnuts.com/yonex-nanoray-700-fx-badminton-1243057.html', 'Exs: http://www.nanotec.com.au/nanoprotect-cs.htm', 'http://tiendas.mediamarkt.es/p/humidificador-philips-hu480301-tecnol-1252366#prodinfotabspec', 'https://clicks.co.za/products/view/clicks-professionals-nano-titanium-ceramic-radial-brush-extra-large', 'https://www.crcindustries.com/products/permanent-head-gasket-block-repair-w-nanotechnology-32-fl-oz-401232.html', 'https://www.alps.com/prod/info/E/HTML/Sensor/Magnetic/HGP_D/HGP_D_list.html', 'http://www.getg.com/G-CLEAN/glass_cleaner.php', 'http://www.panasonic.dk/html/da_dk/produkter/h%c3%a5rpleje+til+m%c3%a6nd/shavere/es-lt31-k503/specifications/8547612/index.html ', 'https://maplehillgolf.com/tommy-armour-evo-golf-bulk-balls.html', 'http://www.samsung.com/sg/consumer/learningresources/silvernano/silvernano/refigerator.html ', 'http://www.logitech.com/en-roeu/product/wireless-headset-h800?crid=36 ', 'http://www.nanodaten.de/index2.php?pid=14&aid=795 ', 'http://www.cutcat.com/item/alkastick/1085/pgc1 \n', 'Exs: http://www.camp-usa.com/products/ice-axes/corsa-nanotech.asp', 'http://www.fujimico.com/catalog/Thermal%20Spray%20Materials/64', 'http://www.squash.com.au/product_info.php?products_id=952', 'https://www.babylisspro.com/product.php?pcID=224_229&product_id=261', 'https://www.amazon.com/scalpmaster-nano-styling-comb-pack/dp/b000vhtu9o/ref=sr_1_1_s_it?s=beauty&ie=utf8&qid=1487693780&sr=1-1&keywords=8-1%2f2"+nano+styling+comb', 'https://www.ravensburger.org/uk/products/games/children-s-games/bugs-in-the-kitchen-game-22261/index.html', 'http://gbproducts.dk/index.php/styling-iron.html ', 'http://www.bilka.dk/sport%20og%20fritid/autoudstyr/bilpleje/udvendig%20pleje/xtreme-glasklar-nano-pro--66743600000%28purchase_other_ds%29 ', 'http://www.creation-direkt.de/page.php?p=50100&id=72 ', 'https://www.amazon.com/kodak-1459395-ultima-picture-4inx6in ...
#
# {'Canada', 'Thailand', 'USA; Australia', 'Japan', 'China', 'Sweden', nan, 'USA; Canada', 'Denamrk', 'Iceland', 'Norway', 'New Zealand', 'Austria', 'UK', 'Rhode Island, USA', 'Unknown', 'Papua New Guinea', 'Spain', 'USA; UK; Canada', 'US', 'Mexico', 'Estonia', 'IL, USA', 'Belgium', 'Italy (USA?)', 'Import from China', 'Lithuania', 'Netherlands', 'USA; Korea', 'Switzerland', 'Singapore', 'China, Singapore', 'Poland', 'China, Israel ', 'Malaysia', 'USA; Amsterdam', 'Germany/UK', 'Thailand; USA', 'Korea; China', 'Russia', 'Prague', 'USA/Canada/Mexico (Glass sold in US) Manufacture started & based in Tokyo', 'Israel', 'Greece', 'Canda', 'UK/US', 'USA; Malaysia', 'Germany', 'Philippines', 'France', 'South Korea', 'Taiwan', 'Arizona, USA', 'Denmark', 'Germany; USA', 'USA', 'Turkey', 'Czech Republic', 'Texas, USA', 'Italy', 'Finland', 'Australia', 'Guatemala', 'Korea; USA', 'Scotland', 'Hong Kong', 'Korea', 'Ireland'}
#
# {'Independent research and tests by the medical industry and the U.S. Military have proven the effectiveness of this anti-odor process.', '"Independent tests prove these repellents can increase visibility 34% on a rainy night, which can add a full second to response time. At 60 mph, that can translate to an 88-foot margin of safety."  See: http://www.nanofilmproducts.com/products/clarity-automotive.htm\n\n', nan, 'Higari Gin Tec - Yes: http://www.hgt.com.hk/english/eindex.htm', 'Larson - certified safe, certified as Clean Air Solvent by California, certified safe for air, water, humans, soils, animals, 105% effective against federal cleaning efficiency tests', 'Explanation of Nanofuse™ technology: http://www.grafalloy.com/newsite/index.php?option=com_content&task=article&id=37&j=tech', 'memory foam treated with special EPA approved formula; patent pending', 'Claim non-hazardous material; 100% safe', 'can kill 40,000 bacteria in 30 minutes under circumstance of 90% humidity and 36iA1iae', 'To access a variety of case studies for all products made with Nansulate™: http://www.nansulate.com/nansulate_industrial_casestudies.htm', '"All our products have undergone extensive laboratory tests to international standards, confirming their effectiveness against bacteria such as Staphylococcus aureus, Bacillus megaterium, Bacillus subtilis, Escherichia coli, Pseudomonas fluorescens and Methicillin-resistant Staphylococcus Aureus (MRSA). In all cases the results show that greater than 99.9% of all bacteria are destroyed within 24 hours. (See: http://agactive.com/faq.html) "100% guaranteed to kill bacteria and control odor"', '"nano-silver eliminates 99.9% of bacteria & hundreds of other disease causing microorganisms, blocking them from contaminating and “odorizing” and providing a safer and cleaner environment"', 'Blue moon - Yes; no leaching of silver', 'Yes - Song Sing Nano', '5-7% harder shots, longest lasting one-piece available, quicker puck release', 'Lead free Certificate for Ceramcor Cookware Testing', 'It looks like Nanofilm has tested all of their products, but no specifics on each.', 'Not really testing but details about the nanomaterials they use: http://www.puckskin.com/faq.html', 'See: http://www.cordura.com/documents/CORDURA_Brand_Fabric_Technologies-Ballistic.pdf', 'environmentally friendly; non-toxic', 'Possibly: http://www.emergencyfiltration.com/faqs.html', 'Yes, see http://www.radshield.com/research_results.cfm', "ARC Outdoors - claim nanosilver won't wash out.", "ARC Outdoors - claim nanosilver won't wash out.  SilverSmart™ claims testing has proven it is safe See: http://www.smartsilver.com/apparel", '"All our products have undergone extensive laboratory tests to international standards, confirming their effectiveness against bacteria such as Staphylococcus aureus, Bacillus megaterium, Bacillus subtilis, Escherichia coli, Pseudomonas fluorescens and Methicillin-resistant Staphylococcus Aureus (MRSA). In all cases the results show that greater than 99.9% of all bacteria are destroyed within 24 hours." (See: http://agactive.com/faq.html) "100% guaranteed to kill bacteria and control odor"', 'Videos proving stain repellent qualities', 'see: http://www.cordura.com/documents/CORDURA_Brand_Fabric_Technologies-Ballistic.pdf', 'EPA registered; "Mold Shield is essentially permanent, and these problems associated with conventional chemicals are not of concern."', 'Claim 100% safe and effective', 'http://breathebetterair.com/labtests.html'}
#
# {'Molecular Property Spectrometer™ (MPS™)', 'They are actually an upholstery manufacturer for various markets. The nano coating is used on their vinyl Dimensions line. They also have a nano coating for marine vehicles. The Nanocide coating is made using silver nanoparticles. ', 'Siemens has hearing aids specifically for kids that use this nanocoating as well.', 'Voridian manufactures technology used by Miller.', 'Silicon/Graphene', '"Nano Protection Kitchen" seals chrome & stainless steel and protects the surface from greasy grease and bacteria, providing an "easy-to-clean" preventive antibacterial effect.\xa0The product can be used, for example, on cooker hoods, kitchen sinks, door handles as well as inside, furniture with "steel look", white goods with large stainless steel surfaces.\xa0The invisible and long-lasting seal provides optimum protection', 'Triple Junction Solar Cell 3G30C-Advanced', 'Toughseal', 'Nano no clonger mentioned on EnviroSystems website. They have a product for horses (EquineTru) that may use nano technology as well.', 'KNT-I13 nanotubes', 'Redington - also includes high modulous carbon, but this does not appear to be nano.', 'Marine Boat Cleaner (MBC)/Deck Polish', '"does not release secondary pollution"', 'does not release secondary pollution', 'The Nanosphere® technology is incorporated into Schoeller Techno-Wool fabric. Contourwear™ sells two types of pants using this technology: "Travel Trousers" and "AnyWear™ Wool-Blend Pants".', 'Can not actually buy bowling balls (the Nanodesu Accu-Swing verison 1-6)  from website. Website claims "We are the largest distributor and manufacturer of bowling supplies in the Far East".  Balls can be found on eBay or here at http://www.123bowl.com/ball.cfm?ballid=4457.', 'The Nanosphere® technology is incorporated into Schoeller® fabric. The shorts are called "3/4 shorts". ', 'The Rio Iron', 'KNT-M35 nanotubes', 'Nano-technology based long-lasting sealant for paintwork or painted plastic components. The paintwork is protected by a coating of modified fluorocarbon nano-particles, which are as hard as glass. It freshens up the colours intensively, has a dirt repellent effect, and has an outstanding droplet run off effect. Depending on conditions, provides protection for up to 9 months.', 'Powermetal Technologies, Inc. supplies the input, not the racket. ', 'RST has several medical products using this technology as well. ', 'Company manufactures this type of nanosilver and provides it to other manufacturers to create products with SmartSilver™', 'Also uses something they call TCN ingredient, but it is not clear what this is or whether it is nano.', 'NANOMYTE® PT-20', 'The air conditioners that use nanotechnology are not available in the US or on the US Carrier website. However, they are for sale in Singapore (See: http://www.longheng.sg/carrier.html)', 'Techniqually all ©PuckSkin products are made with either nanosilver or organic nano? bamboo. ', 'Cleaning and maintenance in one operation Enriches tile colour and structure Rapid pore filler smoothing rough surfaces Produces anti-static slip-retarding protection film', 'KNT-SARC nanotubes', 'Formally product of NDMX™; sold to OnCore Technology ', 'KNT-D90 nanotubes', 'Not available anymore, found other nano remington products', 'Elixir® - coating for guitar strings', "U-Right stuffed animal doesn't seem to be available in U.S. I actually can't find it listed as one of the Texcote applications anymore either.", 'http://gostorehub.com/store.php?asin=B000RWGOJW', '*Actually Nanosilver ginseng technology (verify?) not sure if they are sold in the US', 'Nano-coatings based on silicon dioxide for glass and glazed ceramic', 'liquid suncreen', '\xa0NanoCover Car Glass is a product with many advantages.\xa0On the one hand, it makes rain very light beads and makes the removal of dirt and insect residues from the windshield easier.\xa0Firstly, in the rain you get a considerably better view.\xa0The use of wipers becomes almost sup ...
#
# {1.0, 2.0, 3.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
# {2.0, nan, 3.0, 5.0, 6.0, nan, nan, nan, 8.0, nan, 9.0, nan, 7.0, nan, nan, nan, nan, 4.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
# {0.0, 2.0, nan, 4.0, nan, 5.0, 7.0, 8.0, 9.0, nan, nan, nan, nan, 10.0, nan, 3.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan ...
#
# {2.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
# {2.0, nan, 4.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 25.217385000000004, nan, nan, nan, 32.173905000000005, nan, 33.04347, nan, 33.0, nan, 38.26086000000001, nan, 37.391295, nan, 41.73912, nan, 42.608685, nan, 45.217380000000006, nan, 46.086945, 49.565205000000006, 50.43477, nan, 50.0, nan, 53.043465000000005, nan, 53.913030000000006, nan, 58.26085500000001, nan, 54.782595, nan, 62.60868000000001, nan, 63.478245, 65.21737499999999, nan, nan, 67.82607, 66.956505, 69.56519999999999, nan, 71.30433, nan, 72.17389500000002, nan, 75.65215500000001, 71.30433000000001, nan, 79.13041500000001, nan, 80.86954500000002, 83.47824000000001, 79.99998000000001, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 32.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 59.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 68.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,  ...
#
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 37.97, 38.9, 39.7, 40.55, 41.6, 42.78, 43.86, 44.92, 45.9, 46.45, 47.71, 48.78, 48.6, 50.14, nan, 52.53, 52.43, 53.08, nan, nan, nan, 49.34, nan, 52.02, 52.92, 53.65, 54.5, 55.22, 56.89, 58.66, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 39.5, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 41.38, nan, nan, nan, nan, nan, nan, nan, nan, 44.01, nan, nan, 45.76, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 38.14, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 42.14, nan, nan, nan, nan, nan, nan, nan, 45.64, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, na ...

# %%
df
# Out:
#                                      Product Category Product Subcategory  \
# 0                       Toys / Products for Children      Baby bottle/cup
# 1                       Toys / Products for Children      Baby bottle/cup
# 2                       Toys / Products for Children                  Toy
# 3                              Tools - Personal Care              Brushes
# 4                         Household - hardware, tools               Towel
# ...                                               ...                 ...
# 2780                      Household - hardware, tools                Wire
# 2781                                     Electronics                 Wire
# 2782                                     Electronics     Wireless headset
# 2783                                     Electronics     Wireless headset
# 2784  Coatings, Paints, and Sealants (except textile)                Wood
#
#              Nanomaterial Type       Reason Nano           Manufacturers  \
# 0                       Silver     antibacterial               BabyDream
# 1                       Silver     antibacterial               BabyDream
# 2     Titanium dioxide (2-3nm)           Unknown         NanoBioNet e.V.
# 3                       Silver     antibacterial           Mouthwatchers
# 4                   Nanosilver     dries quickly             Nano Cyclic
# ...                        ...               ...                     ...
# 2780                 AEROTAXY®  improved product             Solvoltaics
# 2781                Nanosilver  improved product         INNOVA DYNAMICS
# 2782                   Unknown           Unknown                Logitech
# 2783                   Unknown           Unknown                Logitech
# 2784                   Unknown   water repellent  New Guard Coatings Ltd
#
#                                                Websites Countries of Origin  \
# 0         http://babydream.koreasme.com/product02a.html               Korea
# 1         http://babydream.koreasme.com/product02a.html               Korea
# 2     http://www.ams-rano.com/en/translate-to-englis...             Germany
# 3     http://www.mouthwatchers.com/collections/super...                 USA
# 4     https://www.amazon.com/nano-cyclic-microfiber-...                 USA
# ...                                                 ...                 ...
# 2780  https://solvoltaics.com/solar-cells-panels-nan...              Sweden
# 2781       http://www.innovadynamics.com/products1.html                 USA
# 2782  http://www.logitech.com/en-roeu/product/wirele...                 USA
# 2783  http://www.logitech.com/en-roeu/product/wirele...                 USA
# 2784  http://www.newguardcoatings.com/uk/product/nan...                  UK
#
#      Testing Notes  Children's Use (1-3)  Exposure (1-10)  Toxicity (1-10)  \
# 0        NaN   NaN                   NaN              NaN              NaN
# 1        NaN   NaN                   NaN              NaN              NaN
# 2        NaN   NaN                   NaN              NaN              NaN
# 3        NaN   NaN                   NaN              NaN              NaN
# 4        NaN   NaN                   NaN              NaN              NaN
# ...      ...   ...                   ...              ...              ...
# 2780     NaN   NaN                   NaN              NaN              NaN
# 2781     NaN   NaN                   NaN              NaN              NaN
# 2782     NaN   NaN                   NaN              NaN              NaN
# 2783     NaN   NaN                   NaN              NaN              NaN
# 2784     NaN   NaN                   NaN              NaN              NaN
#
#       Public Perception (1-5)  Stakeholder Perception (1-5)  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ...                       ...                           ...
# 2780                      NaN                           NaN
# 2781                      NaN                           NaN
# 2782                      NaN                           NaN
# 2783                      NaN                           NaN
# 2784                      NaN                           NaN
#
#       Relative Level of Concern (RLC)  Prioritization Score Using Tool
# 0                                 NaN                            58.66
# 1                                 NaN                            58.66
# 2                                 NaN                            56.89
# 3                                 NaN                            55.22
# 4                                 NaN                            54.50
# ...                               ...                              ...
# 2780                              NaN                              NaN
# 2781                              NaN                              NaN
# 2782                              NaN                              NaN
# 2783                              NaN                              NaN
# 2784                              NaN                              NaN
#
# [2785 rows x 16 columns]

# %%
import pandas as pd
import os

# %%
import pandas as pd
import os

def clean_folder_name(name):
    """Clean string to be used as a folder name."""
    # Remove invalid characters and replace spaces with underscores
    invalid_chars = '<>:"/\\|?*'
    for char in invalid_chars:
        name = name.replace(char, '')
    return name.strip().replace(' ', '_')

def split_excel_to_folders(excel_file, output_dir):
    """
    Split each sheet of an Excel file into separate folders with CSVs.
    
    Args:
        excel_file (str): Path to the Excel file
        output_dir (str): Directory where folders and CSV files will be saved
    """
    # Create main output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Read all sheets
    excel = pd.ExcelFile(excel_file)
    
    # Process each sheet
    for sheet_name in excel.sheet_names:
        # Create clean folder name
        folder_name = clean_folder_name(sheet_name)
        
        # Create folder path
        folder_path = os.path.join(output_dir, folder_name)
        os.makedirs(folder_path, exist_ok=True)
        
        # Read the sheet
        df = pd.read_excel(excel_file, sheet_name=sheet_name)
        
        # Create CSV filename
        csv_filename = f"{folder_name}.csv"
        csv_path = os.path.join(folder_path, csv_filename)
        
        # Save to CSV
        df.to_csv(csv_path, index=False)
        print(f"Saved {csv_filename} in folder {folder_name}")

if __name__ == "__main__":
    # Input Excel file
    excel_file = "./csvs/CPSC Compiled Nano Products Inventory  7.17.19.xlsm"
    
    # Output directory
    output_dir = "cpsc_csv"
    
    # Run the conversion
    split_excel_to_folders(excel_file, output_dir)

# %%
from ontosearch.onto import ontolister, ontocontext
from ontosearch.csv_importer import load_data
from ontosearch.find import matcher
from ontosearch.onto_api import bioportal_search, unpack_superclass
from ontosearch.rdf_print import term_lookup
from json import dump

# %%
from rdflib import Graph

g = Graph()
g.parse("./owlfiles/materialsmine.ttl", format="turtle")
g.serialize(destination="materialsmine.owl", format="xml")

# try and convert kb bio

# %%
database_csv = load_data("./cpsc_csv/Database/Database.csv")

# %%
onto = ontolister(
 onto_dir = ('./owlfiles/')
)

# %%
match, unmatch = matcher(onto, database_csv)

# %%
apiKey = '12df8fd3-39f3-4fca-901e-6fc1bd466ab0'
bioapi = bioportal_search(unmatch, apiKey, em=True, mode='col')
unpack_superclass(bioapi, apiKey)

# %%
finalOnto = ontolister(ontofunc = ontocontext,
 onto_dir = ('owlfiles/')
)

# %%
with open('full_onto_cpsc1.json', 'w') as file:
    dump(finalOnto, file)

# %%
match, unmatch = matcher(onto, database_csv)
csv2 = load_data("./cpsc_csv/Nanomaterial/Nanomaterials.csv")
csv3 = load_data("./cpsc_csv/ProductCategories/ProductCategories.csv")
csv4 = load_data("./cpsc_csv/ProductCategories/ProductCategories.csv")
bioapi = bioportal_search(unmatch, apiKey, em=True, mode='col')
unpack_superclass(bioapi, apiKey)

# %%
from ontosearch.onto import ontolister, ontocontext
from ontosearch.csv_importer import load_data
from ontosearch.find import matcher
from ontosearch.onto_api import bioportal_search, unpack_superclass
from ontosearch.onto_api import bioportal_sample, dict_samp, bio_summary
from ontosearch.rdf_print import table_from_file, term_editor, term_lookup
from ontosearch.rdf_print import basic_rdf, relational_rdf_loader
from ontosearch.rdf_print import primenode, node_one, node_two, multi_editor
# supporting libraries
from rdflib import Graph, URIRef, Literal, BNode
import pandas as pd
import json

# %%
with open('./full_onto_cpsc1.json', 'r', encoding='utf-8') as f:
    onto = json.load(f)
for x in onto:
    print(x)
data_match, data_unmatch = matcher(onto, database_csv, context=True)

# %%
for x in onto:
    print(x)

# %%
cpscGraph = Graph()

# %%
import pandas as pd
import re

def sanitize_category(text: str) -> str:
    """
    Sanitize product category names
    """
    # Convert to string in case we get a float or int
    text = str(text)
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove parentheses and their contents
    text = re.sub(r'\(.*?\)', '', text)
    
    # Replace slashes and hyphens with spaces
    text = re.sub(r'[/\-]', ' ', text)
    
    # Remove any remaining special characters
    text = re.sub(r'[^a-z0-9\s]', '', text)
    
    # Replace multiple spaces with single space
    text = re.sub(r'\s+', ' ', text)
    
    # Trim whitespace
    text = text.strip()
    text = text.replace(' ', '_')
    
    return text

# Read the CSV file
df = pd.read_csv('./cpsc_csv/Database/Database.csv')

# Show some examples before sanitization
print("Before sanitization (sample):")
print(df['Product Category'].head(), "\n")

# Sanitize the Product Category column in place
df['Product Category'] = df['Product Category'].apply(sanitize_category)
df.to_csv('./cpsc_csv/DatabaseSanitized/DatabaseSanitized.csv', index=False)

# %%
database_csv = load_data("./cpsc_csv/DatabaseSanitized/")
database_dfs = table_from_file("./cpsc_csv/DatabaseSanitized/")

# %%
data_match, data_unmatch = matcher(onto, database_csv, context=True)

# %%
cpscGraph = Graph()

# %%
data_match[0]

# %%
basic_rdf(data_match[0], cpscGraph)

# load relational RDF relationships
# this function reads the dataframe structure, and organizes the data
# by providing each row a unique IRI. All other data is organized as
# properties of that row IRI.
relational_rdf_loader(database_dfs, data_match[0], cpscGraph)

# %% [markdown]
# # Ontology Reference
#
# | Abbreviation | Base URI | Full Name & Description |
# |-------------|----------|------------------------|
# | `BAO` | `http://www.bioassayontology.org/bao#` | **BioAssay Ontology** - A semantic description of bioassays and screening results |
# | `BERO` | `http://purl.bioontology.org/ontology/BERO/` | **Biomedical and Environmental Research Ontology** - Describes concepts in biomedical and environmental research |
# | `CHEAR` | `http://purl.obolibrary.org/obo/CHEAR_` | **Children's Health Exposure Analysis Resource Ontology** - Focused on children's environmental health research and exposure analysis |
# | `CHV` | `http://purl.bioontology.org/ontology/CHV/` | **Consumer Health Vocabulary** - Bridges lay and professional medical terminology |
# | `DIDEO` | `http://purl.obolibrary.org/obo/DIDEO_` | **Drug-drug Interaction and Evidence Ontology** - Represents drug-drug interactions and their evidence |
# | `ENM` | `http://purl.enanomapper.org/onto/ENM_` | **eNanoMapper Ontology** - Describes concepts in nanotechnology safety assessment and characterization |
# | `MaterialsMine` | `http://materialsmine.org/ns/` | **Materials Mine Ontology** - Represents materials science and engineering knowledge |
# | `MELO` | `http://purl.bioontology.org/ontology/MELO/` | **MELanoma Ontology** - Specialized vocabulary for melanoma research and treatment |
# | `NPO` | `http://purl.bioontology.org/ontology/npo#NPO_` | **NanoParticle Ontology** - Represents properties of nanoparticles, their experiments and characterizations |
# | `PHARE` | `http://purl.bioontology.org/ontology/PHARE/` | **PHArmacogenomic RElationships Ontology** - Describes relationships between drugs, genes, and clinical outcomes |
# | `SCTO` | `http://purl.bioontology.org/ontology/SCTO/` | **Saudi Clinical Trial Ontology** - Standardizes clinical trial terminology and processes |
# | `THINF` | `http://purl.bioontology.org/ontology/THINF/` | **Thesaurus Inference** - Used for logical inference and relationships between concepts |

# %%
def nodebag(main_parameter_info, sub_parameter_info, rdfgraph):
    term, termiri = main_parameter_info
    starter_term = sub_parameter_info[0][0]
    # check if 'starter term' already in rdfgraph
    if (None, Literal(starter_term), None) in rdfgraph:
        # make a unique rdf "bag" for each row
        for s, p, o in rdfgraph.triples((None, Literal(starter_term), None)):

            # create unique bag for row
            rowbag = BNode()

            # <row> <parameter> <bag>
            rdfgraph.add((s, URIRef(termiri), rowbag))

            # bag description
            bagid = Literal(f"{term} data for entry: {s} ")
            rdfgraph.add((rowbag, URIRef('http://purl.org/dc/elements/1.1/description'), bagid))

            # <relation> <label> 'label'
            rdfgraph.add((URIRef(termiri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal(term)))
            
            #NEW TO V2 - nested the entire below block within the bag-creation loop, instead of in line with the overarching if
            #before, we would make a bag for every row before filling any of them
            #with this change, we now make a bag, fill it, and then move on to the next bag
            
            # stuff the bag, looping thru parameter data
            for column, iri, label in sub_parameter_info:
                # add: <column_iri> rdfs:lable 'label'
                rdfgraph.add((URIRef(iri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal(label)))
                # find the unique bag for each row
                #EDIT - below was original
                #for row, parameter, bag in rdfgraph.triples((None, URIRef(termiri), None)):
                #this variant should work when there's more than one bag per row (i.e. SD2)
                for row, parameter, bag in rdfgraph.triples((None, URIRef(termiri), rowbag)):
                    # loop thru all the pre-existing column relationships
                    for s, p, o in rdfgraph.triples((row, Literal(column), None)):
                        # add: <bag> <column_iri> <data>
                        rdfgraph.add((bag, URIRef(iri), o))
                        # remove: old <row> <column> <data>
                        rdfgraph.remove((s, p, o))

# %%
# First define database and ontology mappings
database_iri = 'http://purl.bioontology.org/ontology/npo#NPO_199'  # Nanotechnology product database

database_edits = [
    ('Product ID', 'http://sbmi.uth.tmc.edu/ontology/ochv#44104'),
    ('Product Subcategory', 'http://semanticscience.org/resource/SIO_001353'),
    ('Nanomaterial Type', 'http://purl.bioontology.org/ontology/npo#NPO_199'),
    ('Reason Nano', 'http://purl.obolibrary.org/obo/CHEBI_33232'),
    ('Manufacturers', 'http://purl.obolibrary.org/obo/OBI_0000835'),
    ('Websites', 'http://semanticscience.org/resource/SIO_000296'),
    ('Countries of Origin', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030'),
    ('Testing', 'http://sbmi.uth.tmc.edu/ontology/ochv#12118'),
    ('Notes', 'http://semanticscience.org/resource/SIO_000136'),
    ('Children\'s Use (1-3)', 'http://hadatac.org/ont/chear#PersonalProductUse'),
    ('Exposure (1-10)', 'http://www.ebi.ac.uk/efo/EFO_0000487'),
    ('Toxicity (1-10)', 'http://purl.bioontology.org/ontology/npo#NPO_1338'),
    ('Public Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030'),
    ('Stakeholder Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0036524'),
    ('Relative Level of Concern (RLC)', 'http://purl.obolibrary.org/obo/MESH_D012306'),
    ('Prioritization Score Using Tool', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0549179'),
]

# First add "is a" relationships
for s, p, o in cpscGraph.triples((None, Literal('Product ID'), None)):
    # add <row> a <material>
    cpscGraph.add((s, URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), URIRef(database_iri)))
    # add <material_iri> <rdfs:label> "material"
    cpscGraph.add((URIRef(database_iri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal('product')))

# Then handle the database edits
for column, iri in database_edits:
    for s, p, o in cpscGraph.triples((None, Literal(column), None)):
        cpscGraph.add((s, URIRef(iri), o))
        cpscGraph.remove((s, p, o))

# After that, create the nodebags
perception_term = ('perception', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030')
perception_rdf = [
    ('Public Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030', 'public perception'),
    ('Stakeholder Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0036524', 'stakeholder perception'),
]
nodebag(perception_term, perception_rdf, cpscGraph)

concern_term = ('concern', 'http://purl.obolibrary.org/obo/MESH_D012306')
concern_rdf = [
    ('Relative Level of Concern (RLC)', 'http://purl.obolibrary.org/obo/MESH_D012306', 'risk level'),
    ('Prioritization Score Using Tool', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0549179', 'priority score'),
    ('Exposure (1-10)', 'http://www.ebi.ac.uk/efo/EFO_0000487', 'exposure'),
    ('Toxicity (1-10)', 'http://purl.bioontology.org/ontology/npo#NPO_1338', 'toxicity'),
]
nodebag(concern_term, concern_rdf, cpscGraph)

# %% [markdown]
# Ontology mappings per column
#
# IMPORTANT: Product Subcategory needs manual curation ->
#
# IMPORTANT: Nanomaterial Type needs manual curation ->
# IMPORTANT: Reason Nano needs manual curation -> http://purl.bioontology.org/ontology/npo#NPO_1490, NPO_199
# IMPORTANT: Manufacturers needs manual curation ->
# IMPORTANT: Websites needs manual curation ->
# IMPORTANT: Countries of Origin needs manual curation ->
# IMPORTANT: Children's Use (1-3) needs manual curation ->
# IMPORTANT: Exposure (1-10) needs manual curation ->
# IMPORTANT: Toxicity (1-10) needs manual curation ->
# IMPORTANT: Public Perception (1-5) needs manual curation ->
# IMPORTANT: Stakeholder Perception (1-5) needs manual curation ->
# IMPORTANT: Relative Level of Concern (RLC) needs manual curation ->
# IMPORTANT: Prioritization Score Using Tool needs manual curation ->

# %%
cpscGraph.serialize(format='turtle', destination='cpscdata_wip0.ttl')

# %%
# need to fix the term ontology and then also the material id ones

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal, BNode
from ontosearch.csv_importer import load_data
from ontosearch.rdf_print import table_from_file, relational_rdf_loader, term_lookup
from ontosearch.onto import ontolister, ontocontext
from ontosearch.find import matcher
import json

# %%
# Create the RDF graph
cpscGraph = Graph()

# %%
# First, load and prepare the CSV data by adding an ID column
df = pd.read_csv("./cpsc_csv/DatabaseSanitized/DatabaseSanitized.csv")
df['ProductID'] = [f"PROD_{str(i).zfill(4)}" for i in df.index]  # Create formatted IDs like PROD_0001
df.to_csv("DatabaseSanitized_with_id.csv", index=False)

# %%
# Load the prepared CSV using ontosearcher functions
database_csv = load_data("./cpsc_csv/DatabaseSanitized_with_id/")
database_dfs = table_from_file("./cpsc_csv/DatabaseSanitized_with_id/")

# %%
# Define database and ontology mappings
database_iri = 'http://purl.bioontology.org/ontology/npo#NPO_199'  # Nanotechnology product database
database_edits = [
    ('ProductID', 'http://purl.org/dc/terms/identifier'),
    ('Product Category', 'http://sbmi.uth.tmc.edu/ontology/ochv#44104'),
    ('Product Subcategory', 'http://semanticscience.org/resource/SIO_001353'),
    ('Nanomaterial Type', 'http://purl.bioontology.org/ontology/npo#NPO_199'),
    ('Reason Nano', 'http://purl.obolibrary.org/obo/CHEBI_33232'),
    ('Manufacturers', 'http://purl.obolibrary.org/obo/OBI_0000835'),
    ('Websites', 'http://semanticscience.org/resource/SIO_000296'),
    ('Countries of Origin', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030'),
    ('Testing', 'http://sbmi.uth.tmc.edu/ontology/ochv#12118'),
    ('Notes', 'http://semanticscience.org/resource/SIO_000136'),
    ('Children\'s Use (1-3)', 'http://hadatac.org/ont/chear#PersonalProductUse'),
    ('Exposure (1-10)', 'http://www.ebi.ac.uk/efo/EFO_0000487'),
    ('Toxicity (1-10)', 'http://purl.bioontology.org/ontology/npo#NPO_1338'),
    ('Public Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030'),
    ('Stakeholder Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0036524'),
    ('Relative Level of Concern (RLC)', 'http://purl.obolibrary.org/obo/MESH_D012306'),
    ('Prioritization Score Using Tool', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0549179'),
]

# %%
with open('./full_onto_cpsc1.json', 'r', encoding='utf-8') as f:
    onto = json.load(f)
data_match, data_unmatch = matcher(onto, database_csv, context=True)
# Out:
# number unmatched terms in Product Subcategory: 207
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 3
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 88
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 10
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Nanomaterial Type: 182
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 16
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 13
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 3
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Reason Nano: 82
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 7
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Manufacturers: 829
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 13
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 10
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Websites: 1852
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Countries of Origin: 69
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 41
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Testing: 20
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Notes: 121
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 2
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Children's Use (1-3): 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Exposure (1-10): 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Toxicity (1-10): 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Public Perception (1-5): 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Stakeholder Perception (1-5): 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Relative Level of Concern (RLC): 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in Prioritization Score Using Tool: 2
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 1
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
# number unmatched terms in ProductID: 2786
#
# RUN: dideo.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: npo-2011-12-08_inferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: bao_complete.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: melanoma_ontology_v4.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: CHV_SKOS_2019.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: ThesaurusInferred.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: enanomapper.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: phare.owl | exact_binary
# matches: 0
# threshold value: 90
# RUN: SCTO.owl | exact_binary
# matches: 0
# threshold value: 90
#
#
# ---------------------
# FINAL MATCHER OUTPUT
#     unmatched:5933    matched:229
# ---------------------

# %%
# Load basic relational RDF relationships
relational_rdf_loader(database_dfs, data_match[0], cpscGraph)  # Empty dict since we're handling mappings manually

# First establish "is a" relationships using ProductID
if (None, Literal('ProductID'), None) in cpscGraph:
    for s, p, o in cpscGraph.triples((None, Literal('ProductID'), None)):
        # add <row> a <product>
        cpscGraph.add((s, URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), URIRef(database_iri)))
        # add <database_iri> <rdfs:label> "product"
        cpscGraph.add((URIRef(database_iri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal('nanotechnology product')))

# Function for implementing nodebag pattern from NKB example
def nodebag(main_parameter_info, sub_parameter_info, rdfgraph):
    term, termiri = main_parameter_info
    starter_term = sub_parameter_info[0][0]
    
    if (None, Literal(starter_term), None) in rdfgraph:
        for s, p, o in rdfgraph.triples((None, Literal(starter_term), None)):
            if (s, URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), URIRef(database_iri)) in rdfgraph:
                # create unique bag for row
                rowbag = BNode()
                # <row> <parameter> <bag>
                rdfgraph.add((s, URIRef(termiri), rowbag))
                # bag description
                bagid = Literal(f"{term} data for entry: {s}")
                rdfgraph.add((rowbag, URIRef('http://purl.org/dc/elements/1.1/description'), bagid))
                # <relation> <label> 'label'
                rdfgraph.add((URIRef(termiri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal(term)))
                
                # stuff the bag with parameter data
                for column, iri, label in sub_parameter_info:
                    # add label
                    rdfgraph.add((URIRef(iri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal(label)))
                    
                    # find and add data
                    for row, param, value in rdfgraph.triples((s, Literal(column), None)):
                        rdfgraph.add((rowbag, URIRef(iri), value))
                        rdfgraph.remove((row, param, value))

# Map the basic columns while verifying types
for column, iri in database_edits:
    for s, p, o in cpscGraph.triples((None, Literal(column), None)):
        if (s, URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), URIRef(database_iri)) in cpscGraph:
            if (s, URIRef(iri), o) in cpscGraph:
                print(f"Warning: Triple already exists for {column}")
            else:
                cpscGraph.add((s, URIRef(iri), o))
                cpscGraph.remove((s, p, o))

# Define and implement perception nodebag
perception_term = ('perception', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030')
perception_rdf = [
    ('Public Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0034030', 'public perception'),
    ('Stakeholder Perception (1-5)', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0036524', 'stakeholder perception'),
]
nodebag(perception_term, perception_rdf, cpscGraph)

# Define and implement concern nodebag
concern_term = ('concern', 'http://purl.obolibrary.org/obo/MESH_D012306')
concern_rdf = [
    ('Relative Level of Concern (RLC)', 'http://purl.obolibrary.org/obo/MESH_D012306', 'risk level'),
    ('Prioritization Score Using Tool', 'http://sbmi.uth.tmc.edu/ontology/ochv#C0549179', 'priority score'),
    ('Exposure (1-10)', 'http://www.ebi.ac.uk/efo/EFO_0000487', 'exposure'),
    ('Toxicity (1-10)', 'http://purl.bioontology.org/ontology/npo#NPO_1338', 'toxicity'),
]
nodebag(concern_term, concern_rdf, cpscGraph)

# Define custom namespace prefixes
namespace_bindings = [
    ('cpsc', URIRef('http://example.org/cpsc/')),  # Base namespace for your data
    ('npo', URIRef('http://purl.bioontology.org/ontology/npo#')),
    ('sio', URIRef('http://semanticscience.org/resource/')),
    ('obo', URIRef('http://purl.obolibrary.org/obo/')),
    ('ochv', URIRef('http://sbmi.uth.tmc.edu/ontology/ochv#')),
    ('efo', URIRef('http://www.ebi.ac.uk/efo/')),
    ('dcterms', URIRef('http://purl.org/dc/terms/')),
    ('dc', URIRef('http://purl.org/dc/elements/1.1/')),
]

# Bind the namespaces
for prefix, namespace in namespace_bindings:
    cpscGraph.bind(prefix, namespace, override=True)

# Serialize the final RDF
cpscGraph.serialize(format="turtle", destination="cpsc_database.ttl")
# Out:
#  IMPORTANT: Product Subcategory needs manual curation
#  IMPORTANT: Nanomaterial Type needs manual curation
#  IMPORTANT: Reason Nano needs manual curation
#  IMPORTANT: Manufacturers needs manual curation
#  IMPORTANT: Websites needs manual curation
#  IMPORTANT: Countries of Origin needs manual curation
#  IMPORTANT: Children's Use (1-3) needs manual curation
#  IMPORTANT: Exposure (1-10) needs manual curation
#  IMPORTANT: Toxicity (1-10) needs manual curation
#  IMPORTANT: Public Perception (1-5) needs manual curation
#  IMPORTANT: Stakeholder Perception (1-5) needs manual curation
#  IMPORTANT: Relative Level of Concern (RLC) needs manual curation
#  IMPORTANT: Prioritization Score Using Tool needs manual curation
#  IMPORTANT: ProductID needs manual curation
# <Graph identifier=N663a8cfbe0e54d09b3707fd9d93c0d33 (<class 'rdflib.graph.Graph'>)>

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal, BNode, Namespace
from ontosearch.csv_importer import load_data
from ontosearch.rdf_print import table_from_file, relational_rdf_loader

# Create the RDF graph
cpscGraph = Graph()

# Define and bind namespaces
CPSC = Namespace('http://example.org/cpsc/')
NPO = Namespace('http://purl.bioontology.org/ontology/npo#')
SIO = Namespace('http://semanticscience.org/resource/')
OBO = Namespace('http://purl.obolibrary.org/obo/')
OCHV = Namespace('http://sbmi.uth.tmc.edu/ontology/ochv#')
EFO = Namespace('http://www.ebi.ac.uk/efo/')
DCTERMS = Namespace('http://purl.org/dc/terms/')

# Using the exact nodebag implementation from NKB example
def nodebag(main_parameter_info, sub_parameter_info, rdfgraph):
    term, termiri = main_parameter_info
    starter_term = sub_parameter_info[0][0]
    
    # check if 'starter term' already in rdfgraph
    if (None, Literal(starter_term), None) in rdfgraph:
        # make a unique rdf "bag" for each row
        for s, p, o in rdfgraph.triples((None, Literal(starter_term), None)):
            # create unique bag for row
            rowbag = BNode()
            # <row> <parameter> <bag>
            rdfgraph.add((s, URIRef(termiri), rowbag))
            # bag description
            bagid = Literal(f"{term} data for entry: {s}")
            rdfgraph.add((rowbag, URIRef('http://purl.org/dc/elements/1.1/description'), bagid))
            # <relation> <label> 'label'
            rdfgraph.add((URIRef(termiri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal(term)))
            
            # stuff the bag with parameter data
            for column, iri, label in sub_parameter_info:
                # add label
                rdfgraph.add((URIRef(iri), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal(label)))
                
                # find and add data
                for s, p, o in rdfgraph.triples((None, Literal(column), None)):
                    rdfgraph.add((rowbag, URIRef(iri), o))
                    rdfgraph.remove((s, p, o))

# # Load and prepare CSV data
# df = pd.read_csv("DatabaseSanitized.csv")
# df['ProductID'] = [f"PROD_{str(i).zfill(4)}" for i in df.index]
# df.to_csv("DatabaseSanitized_with_id.csv", index=False)

# Load data using ontosearcher functions
cpsc_csv = load_data("./cpsc_csv/DatabaseSanitized_with_id/")
cpsc_dfs = table_from_file("./cpsc_csv/DatabaseSanitized_with_id/")

# Load relational RDF relationships
relational_rdf_loader(cpsc_dfs, {}, cpscGraph)

# First establish "is a" relationships using ProductID
if (None, Literal('ProductID'), None) in cpscGraph:
    for s, p, o in cpscGraph.triples((None, Literal('ProductID'), None)):
        # add <row> a <product>
        cpscGraph.add((s, URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), NPO.NPO_199))
        # add <database_iri> <rdfs:label> "product"
        cpscGraph.add((NPO.NPO_199, URIRef('http://www.w3.org/2000/01/rdf-schema#label'), Literal('nanotechnology product')))

# Define perception nodebag
perception_term = ('perception', str(OCHV.C0034030))
perception_rdf = [
    ('Public Perception (1-5)', str(OCHV.C0034030), 'public perception'),
    ('Stakeholder Perception (1-5)', str(OCHV.C0036524), 'stakeholder perception'),
]

# Define concern nodebag
concern_term = ('concern', str(OBO.MESH_D012306))
concern_rdf = [
    ('Relative Level of Concern (RLC)', str(OBO.MESH_D012306), 'risk level'),
    ('Prioritization Score Using Tool', str(OCHV.C0549179), 'priority score'),
    ('Exposure (1-10)', str(EFO.EFO_0000487), 'exposure'),
    ('Toxicity (1-10)', str(NPO.NPO_1338), 'toxicity'),
]

# Apply nodebags
nodebag(perception_term, perception_rdf, cpscGraph)
nodebag(concern_term, concern_rdf, cpscGraph)

# Bind namespaces before serializing
cpscGraph.bind('cpsc', CPSC)
cpscGraph.bind('npo', NPO)
cpscGraph.bind('sio', SIO)
cpscGraph.bind('obo', OBO)
cpscGraph.bind('ochv', OCHV)
cpscGraph.bind('efo', EFO)
cpscGraph.bind('dcterms', DCTERMS)

# Serialize the graph
cpscGraph.serialize(format="turtle", destination="cpsc_database2.ttl")
# Out:
#  IMPORTANT: Product Subcategory needs manual curation
#  IMPORTANT: Nanomaterial Type needs manual curation
#  IMPORTANT: Reason Nano needs manual curation
#  IMPORTANT: Manufacturers needs manual curation
#  IMPORTANT: Websites needs manual curation
#  IMPORTANT: Countries of Origin needs manual curation
#  IMPORTANT: Testing needs manual curation
#  IMPORTANT: Notes needs manual curation
#  IMPORTANT: Children's Use (1-3) needs manual curation
#  IMPORTANT: Exposure (1-10) needs manual curation
#  IMPORTANT: Toxicity (1-10) needs manual curation
#  IMPORTANT: Public Perception (1-5) needs manual curation
#  IMPORTANT: Stakeholder Perception (1-5) needs manual curation
#  IMPORTANT: Relative Level of Concern (RLC) needs manual curation
#  IMPORTANT: Prioritization Score Using Tool needs manual curation
#  IMPORTANT: ProductID needs manual curation
# <Graph identifier=Nfde93d5a01784855a2c278840828ed38 (<class 'rdflib.graph.Graph'>)>

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal, BNode, Namespace
from ontosearch.csv_importer import load_data
from ontosearch.rdf_print import table_from_file, relational_rdf_loader

# Create the RDF graph
cpscGraph = Graph()

# Define namespaces more comprehensively
CPSC = Namespace('http://example.org/cpsc/')
NPO = Namespace('http://purl.bioontology.org/ontology/npo#')
SIO = Namespace('http://semanticscience.org/resource/')
OBO = Namespace('http://purl.obolibrary.org/obo/')
OCHV = Namespace('http://sbmi.uth.tmc.edu/ontology/ochv#')
EFO = Namespace('http://www.ebi.ac.uk/efo/')
DCTERMS = Namespace('http://purl.org/dc/terms/')
RDF = Namespace('http://www.w3.org/1999/02/22-rdf-syntax-ns#')
RDFS = Namespace('http://www.w3.org/2000/01/rdf-schema#')
NCIT = Namespace('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#')

# Bind all namespaces
cpscGraph.bind('cpsc', CPSC)
cpscGraph.bind('npo', NPO)
cpscGraph.bind('sio', SIO)
cpscGraph.bind('obo', OBO)
cpscGraph.bind('ochv', OCHV) 
cpscGraph.bind('efo', EFO)
cpscGraph.bind('dcterms', DCTERMS)
cpscGraph.bind('rdf', RDF)
cpscGraph.bind('rdfs', RDFS)
cpscGraph.bind('ncit', NCIT)

def nodebag(main_parameter_info, sub_parameter_info, rdfgraph):
    term, termiri = main_parameter_info
    starter_term = sub_parameter_info[0][0]
    
    if (None, Literal(starter_term), None) in rdfgraph:
        for s, p, o in rdfgraph.triples((None, Literal(starter_term), None)):
            rowbag = BNode()
            rdfgraph.add((s, URIRef(termiri), rowbag))
            bagid = Literal(f"{term} data for entry: {s}")
            rdfgraph.add((rowbag, DCTERMS.description, bagid))
            rdfgraph.add((URIRef(termiri), RDFS.label, Literal(term)))
            
            for column, iri, label in sub_parameter_info:
                rdfgraph.add((URIRef(iri), RDFS.label, Literal(label)))
                for row_s, row_p, row_o in rdfgraph.triples((s, Literal(column), None)):
                    rdfgraph.add((rowbag, URIRef(iri), row_o))
                    rdfgraph.remove((row_s, row_p, row_o))

# Load data
cpsc_csv = load_data("./cpsc_csv/DatabaseSanitized_with_id/")
cpsc_dfs = table_from_file("./cpsc_csv/DatabaseSanitized_with_id/")

# Load basic relationships
relational_rdf_loader(cpsc_dfs, {}, cpscGraph)

# Establish product type relationships
if (None, Literal('ProductID'), None) in cpscGraph:
    for s, p, o in cpscGraph.triples((None, Literal('ProductID'), None)):
        cpscGraph.add((s, RDF.type, NPO.NPO_199))
        cpscGraph.add((NPO.NPO_199, RDFS.label, Literal('nanotechnology product')))

# Define perception metrics nodebag
perception_term = ('perception metrics', str(OCHV.C0034030))
perception_rdf = [
    ('Public Perception (1-5)', str(OCHV.C0034030), 'public perception'),
    ('Stakeholder Perception (1-5)', str(OCHV.C0036524), 'stakeholder perception'),
]

# Define risk assessment nodebag 
risk_term = ('risk assessment', str(OBO.MESH_D012306))
risk_rdf = [
    ('Relative Level of Concern (RLC)', str(OBO.MESH_D012306), 'risk level'),
    ('Prioritization Score Using Tool', str(OCHV.C0549179), 'priority score'),
    ('Exposure (1-10)', str(EFO.EFO_0000487), 'exposure level'),
    ('Toxicity (1-10)', str(NPO.NPO_1338), 'toxicity level'),
]

# Define product info nodebag
product_term = ('product information', str(NCIT.C93400))
product_rdf = [
    ('Product Category', str(NCIT.C93400), 'product category'),
    ('Product Subcategory', str(NCIT.C93401), 'product subcategory'),
    ('Nanomaterial Type', str(NPO.NPO_1808), 'nanomaterial type'),
    ('Reason Nano', str(NCIT.C42614), 'application purpose'),
    ('Manufacturers', str(NCIT.C43530), 'manufacturer'),
    ('Countries of Origin', str(NCIT.C25464), 'country of origin')
]

# Apply nodebags
nodebag(perception_term, perception_rdf, cpscGraph)
nodebag(risk_term, risk_rdf, cpscGraph)
nodebag(product_term, product_rdf, cpscGraph)

# Serialize with all bindings preserved
cpscGraph.serialize(format="turtle", destination="cpsc_database0.ttl")
# Out:
#  IMPORTANT: Product Subcategory needs manual curation
#  IMPORTANT: Nanomaterial Type needs manual curation
#  IMPORTANT: Reason Nano needs manual curation
#  IMPORTANT: Manufacturers needs manual curation
#  IMPORTANT: Websites needs manual curation
#  IMPORTANT: Countries of Origin needs manual curation
#  IMPORTANT: Testing needs manual curation
#  IMPORTANT: Notes needs manual curation
#  IMPORTANT: Children's Use (1-3) needs manual curation
#  IMPORTANT: Exposure (1-10) needs manual curation
#  IMPORTANT: Toxicity (1-10) needs manual curation
#  IMPORTANT: Public Perception (1-5) needs manual curation
#  IMPORTANT: Stakeholder Perception (1-5) needs manual curation
#  IMPORTANT: Relative Level of Concern (RLC) needs manual curation
#  IMPORTANT: Prioritization Score Using Tool needs manual curation
#  IMPORTANT: ProductID needs manual curation
# <Graph identifier=N1166b7e6089b4ed2b0366bd1e8b18aa2 (<class 'rdflib.graph.Graph'>)>

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal, BNode, Namespace
from ontosearch.csv_importer import load_data
from ontosearch.rdf_print import table_from_file, relational_rdf_loader

# Create the RDF graph
cpscGraph = Graph()

# Define namespaces
CPSC = Namespace('http://example.org/cpsc/')
NPO = Namespace('http://purl.bioontology.org/ontology/npo#')
SIO = Namespace('http://semanticscience.org/resource/')
OBO = Namespace('http://purl.obolibrary.org/obo/')
OCHV = Namespace('http://sbmi.uth.tmc.edu/ontology/ochv#')
EFO = Namespace('http://www.ebi.ac.uk/efo/')
DCTERMS = Namespace('http://purl.org/dc/terms/')
RDF = Namespace('http://www.w3.org/1999/02/22-rdf-syntax-ns#')
RDFS = Namespace('http://www.w3.org/2000/01/rdf-schema#')
NCIT = Namespace('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#')

# Bind all namespaces
prefix_mappings = {
    'cpsc': CPSC,
    'npo': NPO, 
    'sio': SIO,
    'obo': OBO,
    'ochv': OCHV,
    'efo': EFO,
    'dcterms': DCTERMS,
    'rdf': RDF,
    'rdfs': RDFS,
    'ncit': NCIT
}

for prefix, ns in prefix_mappings.items():
    cpscGraph.bind(prefix, ns)

def create_product_node(row, category):
    """Create a node for a product with all its properties"""
    product_uri = URIRef(f"{CPSC}product_{row['ProductID']}")
    
    # Add type 
    cpscGraph.add((product_uri, RDF.type, NPO.NPO_199))
    
    # Add basic properties
    if pd.notna(row['Product Category']):
        cpscGraph.add((product_uri, NCIT.C93400, Literal(row['Product Category'])))
    if pd.notna(row['Product Subcategory']):
        cpscGraph.add((product_uri, NCIT.C93401, Literal(row['Product Subcategory'])))
    if pd.notna(row['Nanomaterial Type']):
        cpscGraph.add((product_uri, NPO.NPO_1808, Literal(row['Nanomaterial Type'])))
    
    # Create perception metrics bag
    perception_bag = BNode()
    cpscGraph.add((product_uri, OCHV.C0034030, perception_bag))
    cpscGraph.add((perception_bag, DCTERMS.description, 
                   Literal(f"perception metrics data for {row['ProductID']}")))
    
    if pd.notna(row['Public Perception (1-5)']):
        cpscGraph.add((perception_bag, OCHV.C0034030, 
                      Literal(row['Public Perception (1-5)'])))
    if pd.notna(row['Stakeholder Perception (1-5)']):
        cpscGraph.add((perception_bag, OCHV.C0036524,
                      Literal(row['Stakeholder Perception (1-5)'])))

    # Create risk assessment bag  
    risk_bag = BNode()
    cpscGraph.add((product_uri, OBO.MESH_D012306, risk_bag))
    cpscGraph.add((risk_bag, DCTERMS.description,
                   Literal(f"risk assessment data for {row['ProductID']}")))
    
    if pd.notna(row['Relative Level of Concern (RLC)']):
        cpscGraph.add((risk_bag, OBO.MESH_D012306, 
                      Literal(row['Relative Level of Concern (RLC)'])))
    if pd.notna(row['Exposure (1-10)']):
        cpscGraph.add((risk_bag, EFO.EFO_0000487,
                      Literal(row['Exposure (1-10)'])))
    if pd.notna(row['Toxicity (1-10)']):
        cpscGraph.add((risk_bag, NPO.NPO_1338,
                      Literal(row['Toxicity (1-10)'])))
        
    # Add product metadata
    if pd.notna(row['Manufacturers']):
        cpscGraph.add((product_uri, NCIT.C43530, Literal(row['Manufacturers'])))
    if pd.notna(row['Countries of Origin']):
        cpscGraph.add((product_uri, NCIT.C25464, Literal(row['Countries of Origin'])))
    if pd.notna(row['Testing']):
        cpscGraph.add((product_uri, OBO.CHMO_0000101, Literal(row['Testing'])))
    if pd.notna(row['Notes']):
        cpscGraph.add((product_uri, DCTERMS.description, Literal(row['Notes'])))

# Load data
df = pd.read_csv("./cpsc_csv/DatabaseSanitized/DatabaseSanitized.csv")
df['ProductID'] = [f'PROD_{str(i).zfill(4)}' for i in df.index]

# Process each product category
for category in df['Product Category'].unique():
    category_df = df[df['Product Category'] == category]
    for _, row in category_df.iterrows():
        create_product_node(row, category)

# Add class labels
cpscGraph.add((NPO.NPO_199, RDFS.label, Literal('nanotechnology product')))
cpscGraph.add((NCIT.C93400, RDFS.label, Literal('product category')))
cpscGraph.add((NCIT.C93401, RDFS.label, Literal('product subcategory')))
cpscGraph.add((NPO.NPO_1808, RDFS.label, Literal('nanomaterial type')))
cpscGraph.add((OCHV.C0034030, RDFS.label, Literal('perception metrics')))
cpscGraph.add((OBO.MESH_D012306, RDFS.label, Literal('risk assessment')))

# Serialize the graph
cpscGraph.serialize(format="turtle", destination="cpsc_database.ttl")
# Out:
# <Graph identifier=N1653fb2675334d138699543b84a1610b (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib import Graph

g = Graph()
g.parse("../mappings/cpsc_database.ttl") 
def rdf_to_networkx_multidigraph(rdf_graph):
    G = nx.MultiDiGraph()
    for s, p, o in rdf_graph:
        # Convert rdflib URIRefs and Literals to strings for node/edge labels
        s_str = str(s)
        p_str = str(p)
        o_str = str(o)
        G.add_node(s_str)
        G.add_node(o_str)
        G.add_edge(s_str, o_str, label=p_str)
    return G

# Usage:
nx_graph = rdf_to_networkx_multidigraph(g)

# %%
def get_node_subgraph(nx_graph, node):
    neighbors = list(nx_graph.neighbors(node)) + list(nx_graph.predecessors(node))
    sub_nodes = set([node] + neighbors)
    subgraph = nx_graph.subgraph(sub_nodes)
    return subgraph

# %%
import matplotlib.pyplot as plt
import networkx as nx

import matplotlib.pyplot as plt
import networkx as nx

def visualize_node_and_connections(nx_graph, node_uri):
    """
    Visualize a node and its direct connections in a networkx.MultiDiGraph.
    - node_uri: string (the URI of the node to visualize)
    """
    node = str(node_uri)
    if node not in nx_graph:
        print(f"Node {node} not found in the graph.")
        return

    # Get neighbors (successors and predecessors)
    neighbors = set(nx_graph.successors(node)).union(nx_graph.predecessors(node))
    sub_nodes = set([node]) | neighbors
    subgraph = nx_graph.subgraph(sub_nodes).copy()

    # Relabel nodes for readability (show only last part of URI)
    def short(n):
        if '#' in n:
            return n.split('#')[-1]
        elif '/' in n:
            return n.split('/')[-1]
        else:
            return n
    mapping = {n: short(n) for n in subgraph.nodes}
    subgraph = nx.relabel_nodes(subgraph, mapping)
    short_node = mapping[node]

    # Prepare edge labels (for MultiDiGraph, may be multiple edges)
    edge_labels = {}
    for u, v, k, d in subgraph.edges(keys=True, data=True):
        label = d.get('label', '')
        if (u, v) in edge_labels:
            edge_labels[(u, v)] += f", {short(label)}"
        else:
            edge_labels[(u, v)] = short(label)

    # Use spring layout with more iterations for clarity
    pos = nx.spring_layout(subgraph, k=0.8, iterations=100)

    plt.figure(figsize=(10, 7))
    nx.draw_networkx_nodes(subgraph, pos, nodelist=[short_node], node_color='orange', node_size=1500)
    nx.draw_networkx_nodes(subgraph, pos, nodelist=[n for n in subgraph.nodes if n != short_node], node_color='lightblue', node_size=1200)
    nx.draw_networkx_labels(subgraph, pos, font_size=12, font_weight='bold')
    nx.draw_networkx_edges(subgraph, pos, arrows=True, arrowstyle='-|>', arrowsize=20, width=2, connectionstyle='arc3,rad=0.1')
    nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels, font_color='green', font_size=10, label_pos=0.5, rotate=False)

    plt.title(f"Node and its connections: {short_node}", fontsize=14)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

    # Print literal attributes, if any
    attrs = nx_graph.nodes[node]
    if attrs:
        print(f"Attributes for node {node}:")
        for k, v in attrs.items():
            print(f"  {k}: {v}")

# %%
from rdflib import Graph

g = Graph()
g.parse("mappings/cpsc_database.ttl", format="turtle")

nx_graph = rdf_to_networkx_multidigraph(g)

# Find the full URI for your node (rdflib expands prefixes)
for node in nx_graph.nodes:
    if node.endswith("product_PROD_0000"):
        print("Node URI:", node)
        visualize_node_and_connections(nx_graph, node)
        break
# Out:
# Node URI: http://example.org/cpsc/product_PROD_0000

# %%
import rdflib
from rdflib import Graph

# %%
g = Graph.parse('../mappings/cpsc_database.ttl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 g = Graph.parse('../mappings/cpsc_database.ttl')
#
# File ~/anaconda3/lib/python3.11/site-packages/rdflib/graph.py:1578, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1483 def parse(
#    1484     self,
#    1485     source: (
#    (...)
#    1493     **args: Any,
#    1494 ) -> Graph:
#    1495     """
#    1496     Parse an RDF source adding the resulting triples to the Graph.
#    1497
#    (...)
#    1575
#    1576     """
# -> 1578     source = create_input_source(
#    1579         source=source,
#    1580         publicID=publicID,
#    1581         location=location,
#    1582         file=file,
#    1583         data=data,
#    1584         format=format,
#    1585     )
#    1586     if format is None:
#    1587         format = source.content_type
#
# File ~/anaconda3/lib/python3.11/site-packages/rdflib/parser.py:676, in create_input_source(source, publicID, location, file, data, format)
#     668 non_empty_arguments = list(
#     669     filter(
#     670         lambda v: v is not None,
#     671         [source, location, file, data],
#     672     )
#     673 )
#     675 if len(non_empty_arguments) != 1:
# --> 676     raise ValueError(
#     677         "exactly one of source, location, file or data must be given",
#     678     )
#     680 input_source = None
#     682 if source is not None:
#
# ValueError: exactly one of source, location, file or data must be given
